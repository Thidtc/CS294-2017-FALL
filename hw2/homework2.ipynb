# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
from plot import *

# %matplotlib inline
# %reload_ext autoreload


def run_plot(args):
    use_legend = False
    if args.legend is not None:
        assert len(args.legend) == len(args.logdir), \
            "Must give a legend title for each set of experiments."
        use_legend = True

    data = []
    if use_legend:
        for logdir, legend_title in zip(args.logdir, args.legend):
            data += get_datasets(logdir, legend_title)
    else:
        for logdir in args.logdir:
            data += get_datasets(logdir)

    if isinstance(args.value, list):
        values = args.value
    else:
        values = [args.value]
    for value in values:
        plot_data(data, value=value)

# %% [markdown]
# # run
# * don't normalize advantage
# * reward to go = False
#
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -dna --exp_name sb_no_rtg_dna
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/sb_no_rtg_dna_CartPole-v0_18-12-2017_19-39-25/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # run
# * don't normalize advantage
# * reward to go = True
#
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -rtg -dna --exp_name sb_rtg_dna
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/sb_rtg_dna_CartPole-v0_18-12-2017_19-47-43/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # run
# * normalize advantage
# * reward to go = True
#
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 1000 -e 5 -rtg --exp_name sb_rtg_na
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/sb_rtg_na_CartPole-v0_18-12-2017_20-22-11/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # run
# * normalize advantage
# * reward to go = False
# * larger batch size
#
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -dna --exp_name lb_no_rtg_dna
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/lb_no_rtg_dna_CartPole-v0_18-12-2017_19-57-12/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # run
# * don't normalize advantage
# * reward to go = True
# * larger batch size
#
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -rtg -dna --exp_name lb_rtg_dna
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/lb_rtg_dna_CartPole-v0_18-12-2017_20-03-14/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # run
# * normalize advantage
# * reward to go = True
# * larger batch size
#
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 5000 -e 5 -rtg --exp_name lb_rtg_na
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/lb_rtg_na_CartPole-v0_18-12-2017_20-08-38/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# * Which gradient estimator has better performance without advantage-centering, the trajectory-centric one, or the one using reward-to-go?
#
# reward-to-go preform better
#
# * Did advantage centering help?
#
# yes, when the model getting to converge, the variance gets lower (although variance centering makes the highest variance higher)
#
# * – Describe what you expected from the math—do the empirical results match the theory?
#
# trajectory-centric uses only the sum reward of the entire trajectory, while reward-to-go uses all, since the reward of the entire trajectory is usually larger, it's more unstable
#
# * Did the batch size make an impact?
# yes

# %% [markdown]
# neural network baseline

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/sb_rtg_lb_CartPole-v0_18-12-2017_20-33-22/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# [GAE](https://danieltakeshi.github.io/2017/04/02/notes-on-the-generalized-advantage-estimation-paper/)
# generalized advantage estimation
#
# $$
# \begin{align}
# \hat{A}_t^{GAE(\gamma,\lambda)} &= (1-\lambda)\Big(\hat{A}_{t}^{(1)} + \lambda \hat{A}_{t}^{(2)} + \lambda^2 \hat{A}_{t}^{(3)} + \cdots \Big) \\
# &= (1-\lambda)\Big(\delta_t^V + \lambda(\delta_t^V + \gamma \delta_{t+1}^V) + \lambda^2(\delta_t^V + \gamma \delta_{t+1}^V + \gamma^2 \delta_{t+2}^V)+ \cdots \Big)  \\
# &= (1-\lambda)\Big( \delta_t^V(1+\lambda+\lambda^2+\cdots) + \gamma\delta_{t+1}^V(\lambda+\lambda^2+\cdots) + \cdots \Big) \\
# &= (1-\lambda)\left(\delta_t^V \frac{1}{1-\lambda} + \gamma \delta_{t+1}^V\frac{\lambda}{1-\lambda} + \cdots\right) \\
# &= \sum_{l=0}^\infty (\gamma \lambda)^l \delta_{t+l}^{V}
# \end{align}
# $$

# %% [markdown]
# ``` bash
# python train_pg.py CartPole-v0 -n 100 -b 1000 -e 1 -rtg -bl --exp_name gae
# ```

# %%
class Argument(object):
    logdir = ['/home/wdl/notebook/DRL/hw2/data/gae_CartPole-v0_18-12-2017_21-11-52/1']
    legend = None
    value = ['AverageReturn', 'StdReturn']
args = Argument()
run_plot(args)
# Out:
# /home/wdl/Code/.env/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
